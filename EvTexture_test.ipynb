# %% [markdown]
# <a href="https://colab.research.google.com/github/DachunKai/EvTexture/blob/main/EvTexture_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download pretrained model and test sets, and config the environment

# %%
# !git clone https://github.com/DachunKai/EvTexture
# !mkdir -p /content/EvTexture/experiments/pretrained_models/EvTexture

# !wget https://github.com/DachunKai/EvTexture/releases/download/v0.0/EvTexture_REDS_BIx4.pth -O /content/EvTexture/experiments/pretrained_models/EvTexture/EvTexture_REDS_BIx4.pth
# !wget https://github.com/DachunKai/EvTexture/releases/download/v0.0/EvTexture_Vimeo90K_BIx4.pth -O /content/EvTexture/experiments/pretrained_models/EvTexture/EvTexture_Vimeo90K_BIx4.pth
# !wget https://github.com/DachunKai/EvTexture/releases/download/v0.0/test_sets_REDS4_h5.zip -O /content/EvTexture/datasets/test_sets_REDS4_h5.zip
# !wget https://github.com/DachunKai/EvTexture/releases/download/v0.0/test_sets_Vid4_h5.zip -O /content/EvTexture/datasets/test_sets_Vid4_h5.zip

# %cd /content/EvTexture/datasets
# !unzip -o test_sets_Vid4_h5.zip
# !unzip -o test_sets_REDS4_h5.zip

# %cd /content/EvTexture
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# Cloning into 'EvTexture'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 246 (delta 69), reused 216 (delta 46), pack-reused 0
# Receiving objects: 100% (246/246), 16.45 MiB | 32.72 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# --2024-07-02 05:39:46--  https://github.com/DachunKai/EvTexture/releases/download/v0.0/EvTexture_REDS_BIx4.pth
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# Test on Vid4 Dataset

# %%
# %cd /content/EvTexture
# !python basicsr/test.py -opt options/test/EvTexture/test_EvTexture_Vid4_BIx4.yml

# %% [markdown]
# Test on REDS4 Dataset

# %%
# %cd /content/EvTexture
# !python basicsr/test.py -opt options/test/EvTexture/test_EvTexture_REDS4_BIx4.yml

# %% [markdown]
# The inference results will be saved under /content/EvTexture/results/EvTexture_Vid4_BIx4 and /content/EvTexture/results/EvTexture_REDS4_BIx4, respectively.
